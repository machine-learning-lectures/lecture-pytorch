# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/00_welcome.ipynb)
#
# # 🔥 PyTorch Gym — PyTorch Operator Practice
#
# Welcome! This is a JupyterLab-based environment for practicing PyTorch operator implementations.
#
# ## 📁 File Layout
#
# Each problem has **two** notebooks:
#
# | File | Description |
# |------|-------------|
# | `01_relu.ipynb` | ✏️ **Blank template** — write your implementation here |
# | `01_relu_solution.ipynb` | 📖 **Reference solution** — check when you're stuck |
#
# ## How to Use
#
# 1. **Open a problem** — pick a blank template like `01_relu.ipynb`
# 2. **Read the description** — the first cell has the problem statement and signature
# 3. **Write your code** — implement in the `✏️ YOUR IMPLEMENTATION HERE` cell
# 4. **Debug** — insert cells freely for `print(x.shape)` etc.
# 5. **Submit** — run the last cell `check("relu")` to see results
# 6. **Stuck?** — call `hint("relu")` for a nudge, or open the `_solution.ipynb`
# 7. **Reset** — click the 🔄 **Reset** button in the toolbar to restore the blank template and practice again
#
# > 💡 Every notebook also has a **Colab** toolbar button and an **Open in Colab** badge — use them to run problems in Google Colab with zero setup.
#
# ## Quick Start
#
# 📖 **Reference solutions in Colab**: [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/01_relu_solution.ipynb) — Start with ReLU. Or use the **Colab** links in the table below for each solution.

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q git+https://github.com/machine-learning-lectures/lecture-pytorch.git#subdirectory=src')
except ImportError:
    pass

# %%
from torch_judge import status
status()

# %% [markdown]
# ## Problem List (40 problems)
#
# ### 🧱 Fundamentals — "Implement X from scratch"
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 1 | ReLU | 🟢 Easy | [Open](01_relu.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/01_relu.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/01_relu.ipynb" target="_blank">Colab</a> | [Open](01_relu_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/01_relu_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/01_relu_solution.ipynb" target="_blank">Colab</a> |
# | 2 | Softmax | 🟢 Easy | [Open](02_softmax.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/02_softmax.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/02_softmax.ipynb" target="_blank">Colab</a> | [Open](02_softmax_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/02_softmax_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/02_softmax_solution.ipynb" target="_blank">Colab</a> |
# | 16 | Cross-Entropy Loss | 🟢 Easy | [Open](16_cross_entropy.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/16_cross_entropy.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/16_cross_entropy.ipynb" target="_blank">Colab</a> | [Open](16_cross_entropy_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/16_cross_entropy_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/16_cross_entropy_solution.ipynb" target="_blank">Colab</a> |
# | 17 | Dropout | 🟢 Easy | [Open](17_dropout.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/17_dropout.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/17_dropout.ipynb" target="_blank">Colab</a> | [Open](17_dropout_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/17_dropout_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/17_dropout_solution.ipynb" target="_blank">Colab</a> |
# | 18 | Embedding | 🟢 Easy | [Open](18_embedding.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/18_embedding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/18_embedding.ipynb" target="_blank">Colab</a> | [Open](18_embedding_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/18_embedding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/18_embedding_solution.ipynb" target="_blank">Colab</a> |
# | 19 | GELU | 🟢 Easy | [Open](19_gelu.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/19_gelu.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/19_gelu.ipynb" target="_blank">Colab</a> | [Open](19_gelu_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/19_gelu_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/19_gelu_solution.ipynb" target="_blank">Colab</a> |
# | 20 | Kaiming Init | 🟢 Easy | [Open](20_weight_init.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/20_weight_init.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/20_weight_init.ipynb" target="_blank">Colab</a> | [Open](20_weight_init_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/20_weight_init_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/20_weight_init_solution.ipynb" target="_blank">Colab</a> |
# | 21 | Gradient Clipping | 🟢 Easy | [Open](21_gradient_clipping.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/21_gradient_clipping.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/21_gradient_clipping.ipynb" target="_blank">Colab</a> | [Open](21_gradient_clipping_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/21_gradient_clipping_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/21_gradient_clipping_solution.ipynb" target="_blank">Colab</a> |
# | 31 | Gradient Accumulation | 🟢 Easy | [Open](31_gradient_accumulation.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/31_gradient_accumulation.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/31_gradient_accumulation.ipynb" target="_blank">Colab</a> | [Open](31_gradient_accumulation_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/31_gradient_accumulation_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/31_gradient_accumulation_solution.ipynb" target="_blank">Colab</a> |
# | 3 | Linear Layer | 🟡 Medium | [Open](03_linear.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/03_linear.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/03_linear.ipynb" target="_blank">Colab</a> | [Open](03_linear_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/03_linear_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/03_linear_solution.ipynb" target="_blank">Colab</a> |
# | 4 | LayerNorm | 🟡 Medium | [Open](04_layernorm.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/04_layernorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/04_layernorm.ipynb" target="_blank">Colab</a> | [Open](04_layernorm_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/04_layernorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/04_layernorm_solution.ipynb" target="_blank">Colab</a> |
# | 7 | BatchNorm | 🟡 Medium | [Open](07_batchnorm.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/07_batchnorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/07_batchnorm.ipynb" target="_blank">Colab</a> | [Open](07_batchnorm_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/07_batchnorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/07_batchnorm_solution.ipynb" target="_blank">Colab</a> |
# | 8 | RMSNorm | 🟡 Medium | [Open](08_rmsnorm.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/08_rmsnorm.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/08_rmsnorm.ipynb" target="_blank">Colab</a> | [Open](08_rmsnorm_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/08_rmsnorm_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/08_rmsnorm_solution.ipynb" target="_blank">Colab</a> |
# | 15 | SwiGLU MLP | 🟡 Medium | [Open](15_mlp.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/15_mlp.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/15_mlp.ipynb" target="_blank">Colab</a> | [Open](15_mlp_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/15_mlp_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/15_mlp_solution.ipynb" target="_blank">Colab</a> |
# | 22 | Conv2d | 🟡 Medium | [Open](22_conv2d.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/22_conv2d.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/22_conv2d.ipynb" target="_blank">Colab</a> | [Open](22_conv2d_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/22_conv2d_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/22_conv2d_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🧠 Attention Mechanisms
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 23 | Cross-Attention | 🟡 Medium | [Open](23_cross_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/23_cross_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/23_cross_attention.ipynb" target="_blank">Colab</a> | [Open](23_cross_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/23_cross_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/23_cross_attention_solution.ipynb" target="_blank">Colab</a> |
# | 5 | Scaled Dot-Product Attention | 🔴 Hard | [Open](05_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/05_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/05_attention.ipynb" target="_blank">Colab</a> | [Open](05_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/05_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/05_attention_solution.ipynb" target="_blank">Colab</a> |
# | 6 | Multi-Head Attention | 🔴 Hard | [Open](06_multihead_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/06_multihead_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/06_multihead_attention.ipynb" target="_blank">Colab</a> | [Open](06_multihead_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/06_multihead_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/06_multihead_attention_solution.ipynb" target="_blank">Colab</a> |
# | 9 | Causal Self-Attention | 🔴 Hard | [Open](09_causal_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/09_causal_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/09_causal_attention.ipynb" target="_blank">Colab</a> | [Open](09_causal_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/09_causal_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/09_causal_attention_solution.ipynb" target="_blank">Colab</a> |
# | 10 | Grouped Query Attention | 🔴 Hard | [Open](10_gqa.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/10_gqa.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/10_gqa.ipynb" target="_blank">Colab</a> | [Open](10_gqa_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/10_gqa_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/10_gqa_solution.ipynb" target="_blank">Colab</a> |
# | 11 | Sliding Window Attention | 🔴 Hard | [Open](11_sliding_window.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/11_sliding_window.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/11_sliding_window.ipynb" target="_blank">Colab</a> | [Open](11_sliding_window_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/11_sliding_window_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/11_sliding_window_solution.ipynb" target="_blank">Colab</a> |
# | 12 | Linear Attention | 🔴 Hard | [Open](12_linear_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/12_linear_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/12_linear_attention.ipynb" target="_blank">Colab</a> | [Open](12_linear_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/12_linear_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/12_linear_attention_solution.ipynb" target="_blank">Colab</a> |
# | 14 | KV Cache Attention | 🔴 Hard | [Open](14_kv_cache.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/14_kv_cache.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/14_kv_cache.ipynb" target="_blank">Colab</a> | [Open](14_kv_cache_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/14_kv_cache_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/14_kv_cache_solution.ipynb" target="_blank">Colab</a> |
# | 24 | RoPE | 🔴 Hard | [Open](24_rope.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/24_rope.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/24_rope.ipynb" target="_blank">Colab</a> | [Open](24_rope_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/24_rope_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/24_rope_solution.ipynb" target="_blank">Colab</a> |
# | 25 | Flash Attention | 🔴 Hard | [Open](25_flash_attention.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/25_flash_attention.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/25_flash_attention.ipynb" target="_blank">Colab</a> | [Open](25_flash_attention_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/25_flash_attention_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/25_flash_attention_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🏗️ Architecture & Adaptation
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 26 | LoRA | 🟡 Medium | [Open](26_lora.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/26_lora.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/26_lora.ipynb" target="_blank">Colab</a> | [Open](26_lora_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/26_lora_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/26_lora_solution.ipynb" target="_blank">Colab</a> |
# | 27 | ViT Patch Embedding | 🟡 Medium | [Open](27_vit_patch.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/27_vit_patch.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/27_vit_patch.ipynb" target="_blank">Colab</a> | [Open](27_vit_patch_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/27_vit_patch_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/27_vit_patch_solution.ipynb" target="_blank">Colab</a> |
# | 13 | GPT-2 Block | 🔴 Hard | [Open](13_gpt2_block.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/13_gpt2_block.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/13_gpt2_block.ipynb" target="_blank">Colab</a> | [Open](13_gpt2_block_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/13_gpt2_block_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/13_gpt2_block_solution.ipynb" target="_blank">Colab</a> |
# | 28 | Mixture of Experts | 🔴 Hard | [Open](28_moe.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/28_moe.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/28_moe.ipynb" target="_blank">Colab</a> | [Open](28_moe_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/28_moe_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/28_moe_solution.ipynb" target="_blank">Colab</a> |
#
# ### ⚙️ Training & Optimization
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 29 | Adam Optimizer | 🟡 Medium | [Open](29_adam.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/29_adam.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/29_adam.ipynb" target="_blank">Colab</a> | [Open](29_adam_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/29_adam_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/29_adam_solution.ipynb" target="_blank">Colab</a> |
# | 30 | Cosine LR Scheduler | 🟡 Medium | [Open](30_cosine_lr.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/30_cosine_lr.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/30_cosine_lr.ipynb" target="_blank">Colab</a> | [Open](30_cosine_lr_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/30_cosine_lr_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/30_cosine_lr_solution.ipynb" target="_blank">Colab</a> |
# | 40 | Linear Regression | 🟡 Medium | [Open](40_linear_regression.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/40_linear_regression.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/40_linear_regression.ipynb" target="_blank">Colab</a> | [Open](40_linear_regression_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/40_linear_regression_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/40_linear_regression_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🎯 Inference & Decoding
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 32 | Top-k / Top-p Sampling | 🟡 Medium | [Open](32_topk_sampling.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/32_topk_sampling.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/32_topk_sampling.ipynb" target="_blank">Colab</a> | [Open](32_topk_sampling_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/32_topk_sampling_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/32_topk_sampling_solution.ipynb" target="_blank">Colab</a> |
# | 33 | Beam Search | 🟡 Medium | [Open](33_beam_search.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/33_beam_search.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/33_beam_search.ipynb" target="_blank">Colab</a> | [Open](33_beam_search_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/33_beam_search_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/33_beam_search_solution.ipynb" target="_blank">Colab</a> |
# | 34 | Speculative Decoding | 🔴 Hard | [Open](34_speculative_decoding.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/34_speculative_decoding.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/34_speculative_decoding.ipynb" target="_blank">Colab</a> | [Open](34_speculative_decoding_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/34_speculative_decoding_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/34_speculative_decoding_solution.ipynb" target="_blank">Colab</a> |
#
# ### 🔬 Advanced
#
# | # | Problem | Difficulty | Template | Solution |
# |:---:|---------|:----------:|:--------:|:--------:|
# | 35 | BPE Tokenizer | 🔴 Hard | [Open](35_bpe.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/35_bpe.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/35_bpe.ipynb" target="_blank">Colab</a> | [Open](35_bpe_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/35_bpe_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/35_bpe_solution.ipynb" target="_blank">Colab</a> |
# | 36 | INT8 Quantization | 🔴 Hard | [Open](36_int8_quantization.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/36_int8_quantization.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/36_int8_quantization.ipynb" target="_blank">Colab</a> | [Open](36_int8_quantization_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/36_int8_quantization_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/36_int8_quantization_solution.ipynb" target="_blank">Colab</a> |
# | 37 | DPO Loss | 🔴 Hard | [Open](37_dpo_loss.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/37_dpo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/37_dpo_loss.ipynb" target="_blank">Colab</a> | [Open](37_dpo_loss_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/37_dpo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/37_dpo_loss_solution.ipynb" target="_blank">Colab</a> |
# | 38 | GRPO Loss | 🔴 Hard | [Open](38_grpo_loss.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/38_grpo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/38_grpo_loss.ipynb" target="_blank">Colab</a> | [Open](38_grpo_loss_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/38_grpo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/38_grpo_loss_solution.ipynb" target="_blank">Colab</a> |
# | 39 | PPO Loss | 🔴 Hard | [Open](39_ppo_loss.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/39_ppo_loss.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/templates/39_ppo_loss.ipynb" target="_blank">Colab</a> | [Open](39_ppo_loss_solution.ipynb) · <a href="https://github.com/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/39_ppo_loss_solution.ipynb" target="_blank">GitHub</a> · <a href="https://colab.research.google.com/github/machine-learning-lectures/lecture-pytorch/blob/master/src/solutions/39_ppo_loss_solution.ipynb" target="_blank">Colab</a> |
#
# ## Useful Commands
#
# ```python
# from torch_judge import check, hint, status
#
# status()                   # Progress dashboard
# check("relu")              # Judge your implementation
# hint("causal_attention")   # Get a hint
# ```
